# %% [markdown]
# This is a _sample_ **jupyter** notebook.

# %%
arr = [5, 8, 3, 2, 4, 6, 7, 9, 1]
sorted_arr = []
sorted_arr = sorted(arr)
print(f"Initial array: {arr}")
print(f"Sorted array: {sorted_arr}")
# Out:
# Initial array: [5, 8, 3, 2, 4, 6, 7, 9, 1]
# Sorted array: [1, 2, 3, 4, 5, 6, 7, 8, 9]
